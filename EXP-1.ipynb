# %%
import numpy as np
student_scores = np.array([
    [85, 78, 92, 88],
    [76, 85, 80, 79],
    [90, 88, 84, 91],
    [70, 75, 78, 72],
    [88, 90, 85, 87],
    [92, 89, 94, 90],
    [60, 65, 70, 68],
    [81, 79, 83, 80],
    [77, 82, 75, 78],
    [89, 84, 88, 86],
    [73, 70, 72, 74],
    [95, 92, 93, 94],
    [68, 72, 70, 69],
    [84, 80, 86, 83],
    [79, 77, 81, 78],
    [91, 87, 90, 89],
    [66, 71, 69, 67],
    [87, 85, 88, 86],
    [74, 76, 73, 75],
    [93, 90, 95, 92],
    [82, 81, 84, 83],
    [69, 74, 72, 70],
    [86, 88, 87, 85],
    [75, 78, 76, 77],
    [94, 91, 93, 92],
    [80, 82, 79, 81],
    [71, 73, 74, 72],
    [88, 86, 89, 87],
    [83, 84, 82, 85],
    [78, 76, 80, 79],
    [90, 89, 91, 88],
    [72, 74, 73, 71]
])
average_scores = np.mean(student_scores, axis=0)
subjects = ["Math", "Science", "English", "History"]
print("Average Score for Each Subject:")
for i in range(len(subjects)):
    print(subjects[i], ":", round(average_scores[i], 2))
highest_index = np.argmax(average_scores)
print("\nSubject with Highest Average Score:", subjects[highest_index])
# Out:
# Average Score for Each Subject:
# Math : 80.81
# Science : 80.97
# English : 82.06
# History : 81.12
#
# Subject with Highest Average Score: English
