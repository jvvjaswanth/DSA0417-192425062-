# %%
import numpy as np
sales_data = np.array([
    [100, 120, 110],
    [200, 210, 190],
    [150, 160, 155]
])
average_price = np.mean(sales_data)
print("Average Price of All Products Sold:", average_price)
# Out:
# Average Price of All Products Sold: 155.0
