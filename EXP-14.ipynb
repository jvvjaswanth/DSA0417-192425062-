# %%
import pandas as pd
# Sample data of customers who made purchases
data = {
    'Customer_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Age': [22, 25, 22, 30, 25, 35, 30, 22, 40, 35],
    'Purchase_Amount': [500, 700, 300, 900, 400, 650, 800, 200, 1000, 750]
}

df = pd.DataFrame(data)

print("Customer Data:")
print(df)
# Out:
# Customer Data:
#    Customer_ID  Age  Purchase_Amount
# 0          101   22              500
# 1          102   25              700
# 2          103   22              300
# 3          104   30              900
# 4          105   25              400
# 5          106   35              650
# 6          107   30              800
# 7          108   22              200
# 8          109   40             1000
# 9          110   35              750
